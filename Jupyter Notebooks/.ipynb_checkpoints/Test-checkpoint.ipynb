# %%
# Import Packages I will need
from lex_processing import * 
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# To show plots in notebook
# %matplotlib inline

# %%
# Path is where the data I want to process is.
path = '/Users/Joe/dropbox/data/Edited Data/Presidents Data/ReaganSpeeches/'

# %%
df = pd.DataFrame()

# %%
for filename in os.listdir(path):
    if filename.endswith('txt'):
        f = open(path + filename)
        raw = f.read()
        # Clear raw of punctuation and tokenize for word counts.
        wordsNoPunct = strip_punctuation(raw)
        hesitations = wordsNoPunct.count('—')
        wordsNoPunct.replace("—", ' ')
        wordsNoPunct = word_tokenize(wordsNoPunct)
        
        words = word_tokenize(raw)
        sents = sent_tokenize(raw)
        processed = preprocess(raw)
        lex = lexical_diversity(wordsNoPunct)
        mls = meanLengthSentence(processed)
        brunets = BrunetsIndex(len(wordsNoPunct), len(set(wordsNoPunct)))
        wordDict = wordCount(processed)
        thetuple = {'Filename': filename, 'TTR': lex, 'Brunets': brunets,
                    'WordCount':len(wordsNoPunct), 
                    'UniqueWords':len(set(wordsNoPunct)), 'MLU': mls,
                    'Hesitations': hesitations}
        finalDict = {**thetuple, **wordDict}
        #df.loc[len(df)] = thetuple
        #temp_df = tempdf.append(thetuple, ignore_index = True)
        df = df.append(finalDict, ignore_index = True)

# %%
# Rearranging Columns
inserted_cols = ['Filename', 'TTR', 'Brunets','WordCount', 'UniqueWords', 'MLU', 'Hesitations']
cols = ([col for col in inserted_cols if col in df] 
        + [col for col in df if col not in inserted_cols])
df = df[cols]

# %%
df = df.fillna(0)

# %%
list(df)
# Out:
# ['Filename',
#  'TTR',
#  'Brunets',
#  'WordCount',
#  'UniqueWords',
#  'MLU',
#  'Hesitations',
#  "''",
#  ',',
#  '.',
#  ':',
#  'CC',
#  'CD',
#  'DT',
#  'EX',
#  'IN',
#  'JJ',
#  'JJR',
#  'JJS',
#  'MD',
#  'NN',
#  'NNP',
#  'NNPS',
#  'NNS',
#  'PDT',
#  'POS',
#  'PRP',
#  'PRP$',
#  'RB',
#  'RBR',
#  'RBS',
#  'RP',
#  'TO',
#  'UH',
#  'VB',
#  'VBD',
#  'VBG',
#  'VBN',
#  'VBP',
#  'VBZ',
#  'WDT',
#  'WP',
#  'WRB',
#  '``',
#  '$',
#  'FW',
#  'WP$']

# %%
df
# Out:
#                           Filename       TTR    Brunets  WordCount  \
# 0   Reagan - Speech19 - Edited.txt  0.264011  14.072659     3515.0
# 1    Reagan - Speech3 - Edited.txt  0.276809  13.794013     3497.0
# 2    Reagan - Speech4 - Edited.txt  0.289337  13.722459     3076.0
# 3   Reagan - Speech28 - Edited.txt  0.269267  14.120388     3153.0
# 4   Reagan - Speech18 - Edited.txt  0.256569  14.309235     3387.0
# 5    Reagan - Speech5 - Edited.txt  0.267256  13.950703     3622.0
# 6    Reagan - Speech2 - Edited.txt  0.262053  14.113500     3526.0
# 7   Reagan - Speech29 - Edited.txt  0.270229  14.040290     3275.0
# 8   Reagan - Speech24 - Edited.txt  0.271889  13.912824     3472.0
# 34  101.0  39.0  22.0  18.0  2.0  3.0  0.0  0.0
# 35   72.0  29.0  19.0  25.0  0.0  5.0  0.0  0.0
# 36   79.0  31.0  24.0  26.0  6.0  2.0  0.0  0.0
# 37  133.0  49.0  24.0  12.0  3.0  2.0  0.0  0.0
# 38   58.0  20.0  26.0  22.0  5.0  0.0  0.0  0.0
# 39   90.0  37.0  26.0  20.0  4.0  7.0  0.0  0.0
# 40   93.0  36.0  37.0  18.0  0.0  9.0  0.0  0.0
# 41  114.0  40.0  32.0  16.0  2.0  4.0  0.0  0.0
# 42   62.0  24.0  19.0  15.0  4.0  2.0  1.0  0.0
# 43   89.0  34.0  34.0  17.0  3.0  2.0  0.0  1.0
# 44   62.0  25.0  21.0   9.0  2.0  0.0  0.0  1.0
# 45   83.0  37.0  36.0  18.0  1.0  2.0  0.0  0.0
#
# [46 rows x 47 columns]

# %%
df.to_csv('test.csv')

# %%
testpath = '/Users/Joe/dropbox/'

# %%
a = pd.read_csv(testpath + "dates.csv")
b = pd.read_csv(testpath + "test.csv")

# %%
a['JDate'] = [datetime.datetime.strptime(x, '%d/%m/%Y') for x in a['Date']]

# %%
a['Julian'] = [get_julian_datetime(x) for x in a['JDate']]

# %%
merged = a.merge(b, on='Filename')

merged = merged.drop(['Unnamed: 0'], axis=1)
merged = merged.drop(['Date'], axis=1)

# %%
merged = merged.sort_values(by=['JDate'])

# %%
merged
# Out:
#                           Filename      JDate     Julian       TTR    Brunets  \
# 0    Reagan - Speech1 - Edited.txt 1981-01-29  2444633.5  0.288203  13.904344
# 11   Reagan - Speech2 - Edited.txt 1981-03-06  2444669.5  0.262053  14.113500
# 22   Reagan - Speech3 - Edited.txt 1981-06-16  2444771.5  0.276809  13.794013
# 33   Reagan - Speech4 - Edited.txt 1981-10-01  2444878.5  0.289337  13.722459
# 41   Reagan - Speech5 - Edited.txt 1981-11-10  2444918.5  0.267256  13.950703
# 42   Reagan - Speech6 - Edited.txt 1981-12-17  2444955.5  0.254031  14.192190
# 43   Reagan - Speech7 - Edited.txt 1982-01-19  2444988.5  0.252181  14.237704
# 44   Reagan - Speech8 - Edited.txt 1982-02-18  2445018.5  0.276530  13.771665
# 45   Reagan - Speech9 - Edited.txt 1982-03-31  2445059.5  0.289800  13.569236
# 1   Reagan - Speech10 - Edited.txt 1982-05-13  2445102.5  0.244284  14.333727
# 2   Reagan - Speech11 - Edited.txt 1982-06-30  2445150.5  0.255527  14.110036
# 3   Reagan - Speech12 - Edited.txt 1982-07-28  2445178.5  0.263613  13.949107
# 4   Reagan - Speech13 - Edited.txt 1982-09-28  2445240.5  0.260281  14.079873
# 5   Reagan - Speech14 - Edited.txt 1982-11-11  2445284.5  0.256214  14.192566
# 6   Reagan - Speech15 - Edited.txt 1983-01-05  2445339.5  0.264789  14.038958
# 7   Reagan - Speech16 - Edited.txt 1983-02-16  2445381.5  0.264000  14.079688
# 8   Reagan - Speech17 - Edited.txt 1983-05-17  2445471.5  0.267261  14.015323
# 10   98.0  41.0  25.0  22.0  3.0  2.0  0.0  0.0
# 11  113.0  32.0  33.0  24.0  1.0  1.0  0.0  0.0
# 12   96.0  37.0  32.0  20.0  2.0  6.0  0.0  0.0
# 13  109.0  37.0  29.0  15.0  0.0  3.0  0.0  0.0
# 14  104.0  38.0  15.0  17.0  5.0  2.0  1.0  0.0
# 15  100.0  27.0  33.0  18.0  3.0  4.0  0.0  0.0
# 16   90.0  37.0  26.0  20.0  4.0  7.0  0.0  0.0
# 17   94.0  41.0  40.0  19.0  5.0  4.0  0.0  0.0
# 18  107.0  38.0  38.0  23.0  2.0  0.0  0.0  0.0
# 19   86.0  36.0  22.0  19.0  0.0  1.0  0.0  0.0
# 20   94.0  39.0  24.0  25.0  3.0  0.0  0.0  0.0
# 21   83.0  40.0  35.0  19.0  1.0  5.0  0.0  0.0
# 22   94.0  27.0  28.0  22.0  5.0  9.0  0.0  1.0
# 23   83.0  39.0  15.0  15.0  1.0  1.0  0.0  0.0
# 24   62.0  26.0  22.0   8.0  2.0  0.0  0.0  0.0
# 25  101.0  39.0  22.0  18.0  2.0  3.0  0.0  0.0
# 26   82.0  36.0  33.0  18.0  5.0  0.0  0.0  0.0
# 27   67.0  33.0  31.0  12.0  2.0  3.0  1.0  0.0
# 28   95.0  32.0  44.0  17.0  0.0  3.0  0.0  0.0
# 29   68.0  18.0  14.0  10.0  3.0  2.0  0.0  0.0
# 30   77.0  18.0  21.0  20.0  1.0  1.0  0.0  0.0
# 31  102.0  30.0  25.0  17.0  8.0  2.0  0.0  0.0
# 32   72.0  29.0  19.0  25.0  0.0  5.0  0.0  0.0
# 33   79.0  31.0  24.0  26.0  6.0  2.0  0.0  0.0
# 34  102.0  18.0  33.0  17.0  2.0  2.0  0.0  0.0
# 35   59.0  30.0  20.0   7.0  2.0  0.0  0.0  0.0
# 36   86.0  41.0  18.0  19.0  3.0  2.0  0.0  0.0
# 37   83.0  37.0  36.0  18.0  1.0  2.0  0.0  0.0
# 38   62.0  24.0  19.0  15.0  4.0  2.0  1.0  0.0
# 39   46.0  26.0  30.0  34.0  4.0  3.0  0.0  0.0
# 40   55.0  19.0  18.0  13.0  8.0  6.0  0.0  0.0
# 41   93.0  36.0  37.0  18.0  0.0  9.0  0.0  0.0
# 42   75.0  21.0  19.0  24.0  0.0  3.0  1.0  0.0
# 43   62.0  24.0  19.0  17.0  2.0  0.0  1.0  0.0
# 44   58.0  20.0  26.0  22.0  5.0  0.0  0.0  0.0
# 45   98.0  28.0  16.0  20.0  7.0  7.0  1.0  0.0
#
# [46 rows x 49 columns]

# %%
# To avoid confusion, rename merged to df
df = merged

# %%
# Calculate some new aggregate columns
df['Nouns'] = df['NN'] + df['NNS']+ df['NNP'] + df['NNPS']
df['Nouns/100'] = df['Nouns'] / 100
df['NounsNormalised'] = df['Nouns'] / df['WordCount']
df['Adjectives'] = df['JJ'] + df['JJR'] + df['JJS']
df['Adjectives/100'] = df['Adjectives'] / 100
df['AdjectivesNormalised'] = df['Adjectives'] / df['WordCount']
df['Adverbs'] = df['RB'] + df['RBR'] + df['RBS']
df['Adverbs/100'] = df['Adverbs'] / 100
df['AdverbsNormalised'] = df['Adverbs'] / df['WordCount']
df['Verbs'] = df['VB'] + df['VBD'] + df['VBG'] + df['VBN'] + df['VBP'] + df['VBZ']
df['Verbs/100'] = df['Verbs'] / 100
df['VerbsNormalised'] = df['Verbs'] / df['WordCount']

# %%
xs = [x for x in range (1,47)]
ys = merged['MLU']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['UniqueWords']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['TTR']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['WordCount']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['Hesitations']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['Brunets']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['Nouns/100']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['Verbs/100']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['Adjectives/100']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['Adverbs/100']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)

# %%
xs = [x for x in range (1,47)]
ys = merged['NounsNormalised']
xs = np.asarray(xs)
trend = np.polyfit(xs, ys, 1) # fit a straight line
plt.plot(xs, ys,'o')
plt.plot(xs,trend[1]+trend[0]*xs)
